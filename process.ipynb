# %%
# !pip install opencc-python-reimplemented
# Out:
# ...
#    ---------------------------------------- 0.0/481.8 kB ? eta -:--:--
#     --------------------------------------- 10.2/481.8 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/481.8 kB 445.2 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/481.8 kB 281.8 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/481.8 kB 479.1 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/481.8 kB 610.6 kB/s eta 0:00:01
#    ------------------- ------------------ 245.8/481.8 kB 942.1 kB/s eta 0:00:01
#    ---------------------------------------  481.3/481.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 481.8/481.8 kB 1.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\n2000\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
from opencc import OpenCC

cc = OpenCC('s2t')  # 簡體轉繁體

def convert_file(filepath):
    ext = os.path.splitext(filepath)[1].lower()
    if ext not in ['.html', '.json', '.md']:
        return
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
    converted = cc.convert(content)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(converted)
    print(f'Converted: {filepath}')

def walk_and_convert(root):
    for dirpath, _, filenames in os.walk(root):
        for filename in filenames:
            convert_file(os.path.join(dirpath, filename))

# 修改為你的根目錄
walk_and_convert(r'c:\Users\n2000\Downloads\open-iching-main\open-iching-main')
# Out:
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\package-lock.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\package.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\Readme.md
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\array-name_dict.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\array-symbol_dict.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\iching.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\order_dict.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\zhuan_dict.json
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\ichuan\tuan.html
# Converted: c:\Users\n2000\Downloads\open-iching-main\open-iching-main\ichuan\tuan.json
# ...

# %%
import json

# 讀取原始 JSON
with open(r'C:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\iching.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# 處理每個卦
for gua in data:
    if 'image' not in gua:
        gua['image'] = ""
    if 'poetry' not in gua:
        gua['poetry'] = ""


# 寫回 JSON
with open(r'C:\Users\n2000\Downloads\open-iching-main\open-iching-main\iching\iching.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)
